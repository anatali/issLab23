# %%
from diagrams import Cluster, Diagram, Edge
from diagrams.custom import Custom
import os
os.environ['PATH'] += os.pathsep + 'C:/Program Files/Graphviz/bin/'

graphattr = {     #https://www.graphviz.org/doc/info/attrs.html
    'fontsize': '22',
}

nodeattr = {   
    'fontsize': '22',
    'bgcolor': 'lightyellow'
}

eventedgeattr = {
    'color': 'red',
    'style': 'dotted'
}
with Diagram('boundarywalker23Arch', show=False, outformat='png', graph_attr=graphattr) as diag:
  with Cluster('env'):
     sys = Custom('','./qakicons/system.png')
     with Cluster('ctxbasicrobot', graph_attr=nodeattr):
          basicrobot=Custom('basicrobot(ext)','./qakicons/externalQActor.png')
     with Cluster('ctxboundarywalk', graph_attr=nodeattr):
          boundarywalker=Custom('boundarywalker','./qakicons/symActorSmall.png')
          tester=Custom('tester','./qakicons/symActorSmall.png')
     boundarywalker >> Edge(color='magenta', style='solid', xlabel='step', fontcolor='magenta') >> basicrobot
     boundarywalker >> Edge(color='blue', style='solid', xlabel='cmd', fontcolor='blue') >> basicrobot
     tester >> Edge(color='blue', style='solid', xlabel='halt', fontcolor='blue') >> boundarywalker
     tester >> Edge(color='blue', style='solid', xlabel='resume', fontcolor='blue') >> boundarywalker
diag
